# %% [markdown]
# # Kebakaran

# %% [markdown]
# ## Page 1

# %% [markdown]
# - Import Libraries
# - Get URL
# - Extracts `h2` for title  and `a` for links
# - Save it to excel

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import glob

# %%
URL = "https://www.cnnindonesia.com/tag/kebakaran"
#URL = "https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0"
page = requests.get(URL)
print(page.text)
# Out:
# <!DOCTYPE html>
# <html lang="id-ID">
#
#     <head>
#     <!-- s: preload JS -->
#     <link rel="preload" href="https://cdn.cnnindonesia.com/cnnid/js/jquery-3.6.0.min.js?v=10.8.7" as="script">
#     <link rel="preload" href="https://cdn.cnnindonesia.com/cnnid/js/iframeResizer.min.js?v=10.8.7" as="script">
#         <!-- e: preload JS -->
#
#     <title>Berita Harian Kebakaran - CNN Indonesia</title>
# <link rel="dns-prefetch" href="https://www.cnnindonesia.com">
#         <link rel="dns-prefetch" href="https://cdn.cnnindonesia.com">
#         <link rel="dns-prefetch" href="https://cdn.detik.net.id">
#         <link rel="dns-prefetch" href="https://securepubads.g.doubleclick.net">
#         <link rel="dns-prefetch" href="https://cdnstatic.detik.com">
#         <link rel="dns-prefetch" href="https://akcdn.detik.net.id">
#         <link rel="dns-prefetch" href="https://www.gstatic.com">
#         <link rel="dns-prefetch" href="https://www.google-analytics.com">
#         <link rel="dns-prefetch" href="https://www.facebook.com">
#         <link rel="dns-prefetch" href="https://partner.googleadservices.com">
#         <link rel="dns-prefetch" href="https://connect.facebook.net">
#         <link rel="dns-prefetch" href="https://connect.detik.com">
#         <link rel="dns-prefetch" href="https://www.googletagmanager.com">
#         <link rel="dns-prefetch" href="https://script.hotjar.com">
#         <link rel="dns-prefetch" href="https://vars.hotjar.com">
#         <link rel="dns-prefetch" href="https://certify-js.alexametrics.com">
#         <link rel="dns-prefetch" href="https://pubads.g.doubleclick.net">
#         <link rel="dns-prefetch" href="https://b.scorecardresearch.com">
#         <link rel="dns-prefetch" href="https://platform.twitter.com">
#         <link rel="dns-prefetch" href="https://mood.detik.com">
#         <link rel="dns-prefetch" href="https://analytic.detik.com">
#         <link rel="dns-prefetch" href="https://newcomment.detik.com">
#         <link rel="dns-prefetch" href="https://comment.detik.com">
#         <link rel="dns-prefetch" href="https://newrevive.detik.com">
#         <link rel="dns-prefetch" href="https://cdn.ampproject.org"><meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">
# <meta name="apple-mobile-web-app-capable" content="yes"/>
# <meta name="apple-itunes-app" content="app-id=925667511"/>
# <meta name="google-play-app" content="app-id=com.cnn.indonesia"/>
#
#
#
#
# 	<meta name="robots" content="index, follow" />
# 	<meta name="googlebot" content="index, follow" />
# 	<meta name="googlebot-news" content="index, follow" />
#
# 	<meta name="dtk:acctype" content="acc-cnnindonesia" />
# 	<meta name="dtk:subacctype" content="desktop" />
# 	<meta name="dtk:namakanal" content="CNNindonesia" />
# 	<meta name="dtk:articledewasa" content="dewasatidak" />
# 	<meta name="dtk:articlehoax" content="default" />
# 	<meta name="dtk:platform" content="desktop" />
# 	<meta name="dtk:keywords" content="cnn, cnn indonesia, indonesia, kebakaran, kebakaran adalah, berita kebakaran, kebakaran terbaru, kebakaran hari ini, peristiwa kebakaran" />
# 	<meta name="dtk:thumbnailUrl" content="https://cdn.cnnindonesia.com/cnnid/images/logo_cnn_fav.png?v=10.8.7" />
# 	<meta name="dtk:custom-title" content="berita harian kebakaran - cnn indonesia" />
# 	<meta name="dtk:custom-type" content="tag" />
#
# <meta name="platform" content="desktop" />
# <meta name="keywords" content="cnn, cnn indonesia, indonesia, kebakaran, kebakaran adalah, berita kebakaran, kebakaran terbaru, kebakaran hari ini, peristiwa kebakaran" itemprop="keywords" />
# <meta name="description" content="Berita Kebakaran terbaru dan terlengkap" />
# <meta name="twitter:card" content="summary_large_image"/>
# <meta name="twitter:site" content="@CNNindonesia"/>
# <meta name="twitter:site:id" content="17128975" />
# <meta name="twitter:creator" content="@CNNindonesia" />
# <meta name="twitter:description" content="Berita Kebakaran terbaru dan terlengkap" />
# <meta name="twitter:image:src" content="https://cdn.cnnindonesia.com/cnnid/images/logo_cnn_fav.png?v=10.8.7" />
# <meta property="fb:pages" content="695605000462574" />
# <meta property="fb:app_id" content="902258536467731" />
# <meta property="article:author" content="https://www.facebook.com/CNNIndonesia" itemprop="author" />
# <meta property="article:publisher" content="https://www.facebook.com/CNNIndonesia" />
# <meta property="og:site_name" content="CNNindonesia"/>
# <meta property="og:title" content="Berita Harian Kebakaran - CNN Indonesia"/>
# <meta property="og:url" content="https://www.cnnindonesia.com/tag/kebakaran"/>
# <meta property="og:description" content="Berita Kebakaran terbaru dan terlengkap" />
# <meta property="og:image" content="https://cdn.cnnindonesia.com/cnnid/images/logo_cnn_fav.png?v=10.8.7" />
# <meta property="og:image:width" content="650" />
# <meta property="og:image:height" content="366" />
# <meta property="og:type" content="article" />
# <link rel="canonical" href="https://www.cnnindonesia.com/tag/kebakaran" />
#
# <link rel="apple-touch-icon" href="https://cdn.cnnindonesia.com/cnnid/mobile/images/logo__cnn.png?v=10.8.7" />
# <link rel="android-touch-icon" href="https://cdn.cnnindonesia.com/cnnid/mobile/images/logo__cnn.png?v=10.8.7" />
# <link rel="shortcut icon" href="https://cdn.cnnindonesia.com/cnnid/mobile/images/logo__cnn.png?v=10.8.7">
# <link rel="shortcut icon" href="https://cdn.cnnindonesia.com/cnnid/mobile/images/logo__cnn.png?v=10.8.7" type="image/x-icon" />
# <link href="https://plus.google.com/+Cnnindonesiadotcom/" rel="publisher" />
#
#   <link rel="amphtml" href="https://www.cnnindonesia.com/tag/kebakaran/amp">
#
#
#
#
#
#
#     <meta name="robots" content="max-snippet:-1">
#
#     <script type="text/javascript">
#         var EO_SUBCAT   = "";
#         var base_url    = "https://www.cnnindonesia.com/";
#         const asset_version = "10.8.7";
#         const rekomendasiTokenKey = '346516';
#         var asset_url   = "https://cdn.cnnindonesia.com/cnnid/";
#             </script>
#
#     <link rel="stylesheet" type="text/css" href="https://cdn.cnnindonesia.com/cnnid/css/cb_dinamis.css?v=10.8.7" />
#     <link rel="stylesheet" type="text/css" href="https://cdn.cnnindonesia.com/cnnid/css/loader.css?v=10.8.7" />
#
#
#             <link rel="stylesheet" type="text/css" href="https://cdn.cnnindonesia.com/cnnid/css/style.css?v=10.8.7" />
#
#
#     <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/jquery-3.6.0.min.js?v=10.8.7"></script>
#
#
#     <meta name="site_name" content="cnn_tagsite">
#
#     <script type="text/javascript">var dtkGTMDL={data:{},getMeta:function(prop,val){e=document.head.querySelector("["+prop+"=\""+val+"\"]");if(e!==null){return e.content}
#         return null},addDataLayer:function(prop,metaKey,dlKey=null){if(dlKey===null){dlKey=metaKey}
#         val=dtkGTMDL.getMeta(prop,metaKey);if(val===null||val==""){return}
#         dtkGTMDL.data[dlKey]=val},addCustomDimension:function(arr){for(i=0;i<arr.length;i++){switch(arr[i]){case "kanalid":dtkGTMDL.addDataLayer("name","kanalid");break;case "articleid":dtkGTMDL.addDataLayer("name","articleid");break;case "articletype":dtkGTMDL.addDataLayer("name","articletype");break;case "createdate":dtkGTMDL.addDataLayer("name","createdate");break;case "publishdate":dtkGTMDL.addDataLayer("name","publishdate");break;case "keyword":dtkGTMDL.addDataLayer("name","keyword");break;case "idfokus":dtkGTMDL.addDataLayer("name","idfokus");break;case "namafokus":dtkGTMDL.addDataLayer("name","namafokus");break;case "pagesize":dtkGTMDL.addDataLayer("name","pagesize");break;case "pagenumber":dtkGTMDL.addDataLayer("name","pagenumber");break;case "videopresent":dtkGTMDL.addDataLayer("name","videopresent");break;case "video_id":dtkGTMDL.addDataLayer("name","video_id");break;case "contenttype":dtkGTMDL.addDataLayer("name","contenttype");break;case "platform":dtkGTMDL.addDataLayer("name","platform");break;case "tag":dtkGTMDL.addDataLayer("name","tag");break;case "author":dtkGTMDL.addDataLayer("name","author");break;case "hl_nhl_wp":dtkGTMDL.addDataLayer("name","hl_nhl_wp");break;case "hl_nhl_kanal":dtkGTMDL.addDataLayer("name","hl_nhl_kanal");break;default:break}}},generate:function(){contenttype=dtkGTMDL.getMeta("name","contenttype");dtkGTMDL.addCustomDimension(["kanalid","articleid","articletype","createdate","publishdate","keyword","idfokus","namafokus","pagesize","pagenumber","videopresent","video_id","contenttype","platform","tag","author"]);dtkGTMDL.data.event="articlePush";return dtkGTMDL.data}}
#         dataLayer=[dtkGTMDL.generate()]</script>
#     <script type="text/javascript">
#                             console.log = function() {}
#                             console.info = function() {}
#                         </script>
#
#
#     <!-- Start Facebook Pixel Code -->
#     <script>
#     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#     n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#     document,'script','//connect.facebook.net/en_US/fbevents.js');
#
#     fbq('init', '1047303935301449');
#     fbq('track', "PageView");
#
#     </script>
#
#     <!-- iframeResizerJS -->
#     <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/iframeResizer.min.js?v=10.8.7"></script>
#
#     <noscript><img height="1" width="1" style="display:none"
#     src="https://www.facebook.com/tr?id=1047303935301449&ev=PageView&noscript=1"
#     /></noscript>
#     <!-- End Facebook Pixel Code -->
#
#     <!-- s:banner taghead -->
#
# <link rel="stylesheet" type="text/css" href="https://cdn.detik.net.id/commerce/desktop/css/detik.ads.css">
# <script src="https://cdn.detik.net.id/commerce/commerce/dtk_commerce.js"></script>    <!-- e:banner taghead -->
#
#     <!-- S: Pemanggilan GTM -->
#     <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MMTX7HV');</script>
# <!-- End Google Tag Manager -->    <!-- E: Pemanggilan GTM -->
#
# </head>
#
#             <body class="">
#
#         <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MMTX7HV"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#                     <!-- s:banner skinner -->
#                         <!-- e:banner skinner -->
#
#             <!-- s:banner topframe -->
#                         <!-- e:banner topframe -->
#
#             <!-- s:banner popups -->
#                         <!-- e:banner popups -->
#
#             <!-- s:banner sto -->
#                         <!-- e:banner sto -->
#
#             <!-- s:banner popups_pawai17 -->
#                         <!-- e:banner popups_pawai17 -->
#
#             <!-- s:banner balloonads -->
#                         <!-- e:banner balloonads -->
#
#             <!-- s:banner bottomframe -->
#                         <!-- e:banner bottomframe -->
#
#         <header id="header">
#
#     <!-- s:banner leaderboard -->
#     <div class="lb_wrap">
#             </div>
#     <!-- e:banner leaderboard -->
#
#     <div id="nav" class="sticky">
#
#         <div class="container">
#             <a href="https://www.cnnindonesia.com/" class="gtm_logo_cnnindonesia" dtr-evt="header" dtr-sec="logo cnn" dtr-act="logo cnn" onclick="_pt(this)">
#                 <img id="logo" src="https://cdn.cnnindonesia.com/cnnid/images/logo.png?v=10.8.7" alt="CNN Indonesia" >
#             </a>
#
#             <div id="nav_right">
#
#                 <!-- s:login -->
#                 <div class="dropdown hover fr" id="nav_user">
#     <a id="connectDetikUName" href="#" dtr-evt="header" dtr-sec="thumbnail detikid" dtr-act="thumbnail detikid" dtr-ttl="thumbnail" onclick="_pt(this)">
#         <span class="lqd" id="connectDetikAvatar">
#             <div class="loader">Loading...</div>
#         </span>
#     </a>
#     <div class="dropdown_menu">
#         <div class="pd20" id="UserMenu">
#         </div>
#     </div>
#
#     <!--s:detikconnect-client-->
#             <script defer type="text/javascript" src="https://cdn.detik.net.id/libs/dc/v1/detikconnect_auto_login.js"></script>
#         <script type='text/javascript'>
#         $(document).ready(function() {
#             detikConnectAutoLogin('10027', false, onLoginClient);
#         });
#         </script>
#
#     <script type='text/javascript'>
#         function onLoginClient (data){
#             $('.loader').remove()
#             let default_image = 'https://cdn.cnnindonesia.com/cnnid/images/user.png?v=10.8.7';
#             const dcUrl = 'https://connect.detik.com/dashboard/';
#             if (data.is_login) {
#                 $('#connectDetikUName').attr('href', dcUrl);
#                 $('#connectDetikAvatar').attr('src', data.avatar);
#                 $('#connectDetikAvatar').css({'background-image': `url(${data.avatar})`, 'background-size': '100% auto'});
#
#                 $('#UserMenu').append(`
#                     <a href="${dcUrl}" target="_blank">${data.first_name} ${data.last_name}</a>
#                     <a href="https://connect.detik.com/oauth/signout?redirectUrl=https%3A%2F%2Fwww.cnnindonesia.com%2Ftag%2Fkebakaran"
#                         class="gtm_keluar_cnnindonesia HasLogin"
#                         dtr-evt="header"
#                         dtr-sec="logout"
#                         dtr-act="logout"
#                     >Keluar</a>
#                 `);
#             } else {
#                 $('#connectDetikAvatar').attr('src', default_image);
#                 $('#connectDetikAvatar').css('background-image', `url(${default_image})`);
#
#                 $('#UserMenu').append(`
#                     <a href="https://connect.detik.com/accounts/register?clientId=10027&redirectUrl=https%3A%2F%2Fwww.cnnindonesia.com%2Fauthorize&backURL=https%3A%2F%2Fwww.cnnindonesia.com%2Ftag%2Fkebakaran"
#                         class="daftar to_reg NotLogin gtm_daftar_cnnindonesia"
#                         dtr-evt="header"
#                         dtr-sec="register"
#                         dtr-act="register"
#                         onclick="_pt(this)"
#                     >Daftar</a>
#                     <a href="https://connect.detik.com/oauth/authorize?clientId=10027&redirectUrl=https%3A%2F%2Fwww.cnnindonesia.com%2Fauthorize%3Fu%3Dhttps%3A%2F%2Fwww.cnnindonesia.com%2Ftag%2Fkebakaran&backURL=https%3A%2F%2Fwww.cnnindonesia.com%2Ftag%2Fkebakaran"
#                         class="masuk to_login NotLogin"
#                         class="gtm_masuk_cnnindonesia"
#                         dtr-evt="header"
#                         dtr-sec="login"
#                         dtr-act="login"
#                         onclick="_pt(this)"
#                     >Masuk</a>
#                 `);
#             }
#         }
#     </script>
#     <!--e:detikconnect-client-->
# </div>
#                 <!-- e:login -->
#
#                 <div id="nav_search" class="fr">
#                     <a href="#" dtr-evt="header" dtr-sec="search" dtr-act="search" onclick="_pt(this)"><i class="icon icon-search"></i></a>
#                     <form action="https://www.cnnindonesia.com/search/" id="search_form" method="get">
#                         <input type="text" name="query" placeholder="Kata kunci..." required>
#                         <button type="submit"><i class="icon icon-search"></i></button>
#                         <a href="#" id="nav_search_close"><i class="icon icon-close"></i></a>
#                     </form>
#                 </div>
#                 <div class="dropdown hover lainnya fr">
#                     <a href="#" dtr-evt="header" dtr-sec="lainnya" dtr-act="lainnya" onclick="_pt(this)">RAGAM <span class="caret"></span></a>
#
#                     <div class="dropdown_menu">
#                         <div class="grid_row d-flex pd20">
#
#                             <div class="col_3 pr20 dropdown_menu-item">
#                                 <a href="https://www.cnnindonesia.com/foto" class="gtm_navbar_foto" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="Foto" dtr-ttl="ragam">Foto</a>
#                                 <a href="https://www.cnnindonesia.com/video" class="gtm_navbar_video" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="Video" dtr-ttl="ragam">Video</a>
#                                 <a href="https://www.cnnindonesia.com/infografis" class="gtm_navbar_infografis" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="Infografis" dtr-ttl="ragam">Infografis</a>
#                                 <a href="https://www.cnnindonesia.com/indeks" class="gtm_navbar_indeks" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="Indeks" dtr-ttl="ragam">Indeks</a>
#                             </div>
#
#                             <div class="col_3 pr20 dropdown_menu-item">
#                                 <a href="https://www.cnnindonesia.com/fokus" class="gtm_navbar_fokus" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="Fokus" dtr-ttl="ragam">Fokus</a>
#                                 <a href="https://www.cnnindonesia.com/kolom" class="gtm_navbar_kolom" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="Kolom" dtr-ttl="ragam">Kolom</a>
#                                 <a href="https://www.cnnindonesia.com/terpopuler" class="gtm_navbar_kolom" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="Terpopuler" dtr-ttl="ragam">Terpopuler</a>
#                             </div>
#
#                             <div class="col_6 pl10 dropdown_menu-item f18">
#                                 <a href="https://www.cnnindonesia.com/pemilu2024" dtr-evt="header" dtr-sec="pemilu" dtr-act="pemilu" onClick="_pt(this)">Kanal Pemilu Tepercaya</a>
#                                 <section data-name="cnn-id" data-target="block/ragam-feature"></section>
#                                 <a href="https://www.cnnindonesia.com/features" dtr-evt="header" dtr-sec="features" dtr-act="features" onClick="_pt(this)">Features</a>
#                             </div>
#
#                         </div>
#                     </div>
#                 </div>
#             </div>
#
#             <ul id="nav_menu">
#     <li><a href="https://www.cnnindonesia.com/" class="gtm_navbar_home" dtr-evt="header" dtr-sec="" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="1" dtr-ttl="Home">Home</a></li>
#                     <li class="dropdown hover">
#         <a href="https://www.cnnindonesia.com/nasional" class="gtm_navbar_nasional" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="2" dtr-ttl="Nasional">Nasional</a>
#
#         <div class="dropdown_menu">
#             <div class="container mt20 mb20">
#                 <div class="grid_row">
#
#                     <div class="col_2">
#                         <div class="f13 mt15 mb15"></div>
#
#                                                                                     <a href="https://www.cnnindonesia.com/nasional/politik">Politik</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/nasional/hukum-kriminal">Hukum & Kriminal</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/nasional/peristiwa">Peristiwa</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/nasional/pemilu">Pemilu 2024</a>
#                                                                         </div>
#
#                     <div class="col_8 pr20">
#                         <div class="box">
#                             <div class="title_box">BERITA TERBARU</div>
#                             <div class="grid_row gap cols">
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/nasional/20230524203912-12-953654/polisi-tetapkan-3-tersangka-kasus-mafia-tanah-senilai-rp18-t-di-jakut">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2021/09/08/ilustrasi-tindakan-kriminal-1_169.jpeg?w=230&q=90" alt="Polisi Tetapkan 3 Tersangka Kasus Mafia Tanah Senilai Rp1,8 T di Jakut">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Polisi Tetapkan 3 Tersangka Kasus Mafia Tanah Senilai Rp1,8 T di Jakut</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/nasional/20230524203827-12-953653/densus-88-tangkap-seorang-terduga-teroris-di-kota-malang">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2020/11/23/ilustrasi-wanita-di-borgol-dan-penjara-2_169.jpeg?w=230&q=90" alt="Densus 88 Tangkap Seorang Terduga Teroris di Kota Malang">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Densus 88 Tangkap Seorang Terduga Teroris di Kota Malang</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/nasional/20230524202830-32-953652/dasco-bantah-dugaan-gerindra-terima-duit-kasus-bakti-kominfo">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2022/07/13/wakil-ketua-dpr-sufmi-dasco-ahmad-1_169.jpeg?w=230&q=90" alt="Dasco Bantah Dugaan Gerindra Terima Duit Kasus BAKTI Kominfo">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Dasco Bantah Dugaan Gerindra Terima Duit Kasus BAKTI Kominfo</h2>
#                                     </a>
#                                 </article>
#                                                             </div>
#                         </div>
#                     </div>
#
#                     <!-- s:banner logonavigasi -->
#                                          <!-- e:banner logonavigasi -->
#
#                 </div>
#             </div>
#         </div>
#
#     </li>
#                     <li class="dropdown hover">
#         <a href="https://www.cnnindonesia.com/internasional" class="gtm_navbar_internasional" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="3" dtr-ttl="Internasional">Internasional</a>
#
#         <div class="dropdown_menu">
#             <div class="container mt20 mb20">
#                 <div class="grid_row">
#
#                     <div class="col_2">
#                         <div class="f13 mt15 mb15"></div>
#
#                                                                                     <a href="https://www.cnnindonesia.com/internasional/asean">Asean</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/internasional/asia-pasifik">Asia Pasifik</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/internasional/timur-tengah">Timur Tengah</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/internasional/eropa-amerika">Eropa Amerika</a>
#                                                                         </div>
#
#                     <div class="col_8 pr20">
#                         <div class="box">
#                             <div class="title_box">BERITA TERBARU</div>
#                             <div class="grid_row gap cols">
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/internasional/20230524112712-134-953338/pembakaran-al-quran-di-rusia-pemimpin-chechen-murka-tuduh-ukraina">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2022/03/14/pemimpin-chechen-ramzan-kadyrov_169.jpeg?w=230&q=90" alt="Pembakaran Al Quran di Rusia, Pemimpin Chechen Murka Tuduh Ukraina">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Pembakaran Al Quran di Rusia, Pemimpin Chechen Murka Tuduh Ukraina</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/internasional/20230524121645-134-953364/bos-wagner-salahkan-rusia-belgorod-diserang-pejabat-pura-pura-bodoh">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2023/02/13/pendiri-wagner-group-yevgeny-prigozhin_169.jpeg?w=230&q=90" alt="Bos Wagner Salahkan Rusia Belgorod Diserang: Pejabat Pura-pura Bodoh">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Bos Wagner Salahkan Rusia Belgorod Diserang: Pejabat Pura-pura Bodoh</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/internasional/20230524181517-113-953595/kenapa-kashmir-sensitif-sampai-china-saudi-ancam-boikot-forum-g20">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2021/01/09/skardu-valley-pakistan_169.jpeg?w=230&q=90" alt="Kenapa Kashmir Sensitif sampai China-Saudi Ancam Boikot Forum G20?">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Kenapa Kashmir Sensitif sampai China-Saudi Ancam Boikot Forum G20?</h2>
#                                     </a>
#                                 </article>
#                                                             </div>
#                         </div>
#                     </div>
#
#                     <!-- s:banner logonavigasi -->
#                                          <!-- e:banner logonavigasi -->
#
#                 </div>
#             </div>
#         </div>
#
#     </li>
#                     <li class="dropdown hover">
#         <a href="https://www.cnnindonesia.com/ekonomi" class="gtm_navbar_ekonomi" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="4" dtr-ttl="Ekonomi">Ekonomi</a>
#
#         <div class="dropdown_menu">
#             <div class="container mt20 mb20">
#                 <div class="grid_row">
#
#                     <div class="col_2">
#                         <div class="f13 mt15 mb15"></div>
#
#                                                                                     <a href="https://www.cnnindonesia.com/ekonomi/keuangan">Keuangan</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/ekonomi/energi">Energi</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/ekonomi/bisnis">Bisnis</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/ekonomi/makro">Makro</a>
#                                                                         </div>
#
#                     <div class="col_8 pr20">
#                         <div class="box">
#                             <div class="title_box">BERITA TERBARU</div>
#                             <div class="grid_row gap cols">
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/ekonomi/20230524201032-92-953644/krl-bandara-soetta-tambah-jadi-56-perjalanan-mulai-1-juni-2023">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2023/03/29/pengadaan-rangkaian-krl-10_169.jpeg?w=230&q=90" alt="KRL Bandara Soetta Tambah Jadi 56 Perjalanan Mulai 1 Juni 2023">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">KRL Bandara Soetta Tambah Jadi 56 Perjalanan Mulai 1 Juni 2023</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/ekonomi/20230524150751-92-953509/inflasi-inggris-tak-lagi-dua-digit-pertama-kali-sejak-agustus-2022">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2023/03/23/inflasi-inggris-sentuh-level-tertinggi-45-tahun-terakhir-3_169.jpeg?w=230&q=90" alt="Inflasi Inggris Tak Lagi Dua Digit, Pertama Kali Sejak Agustus 2022">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Inflasi Inggris Tak Lagi Dua Digit, Pertama Kali Sejak Agustus 2022</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/ekonomi/20230524190122-92-953612/viral-aksi-bos-blue-bird-nyamar-jadi-sopir-taksi-keliling-jakarta">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2023/05/24/sigit-djokosoetono-menyamar-jadi-sopir-taksi-blue-bird_169.jpeg?w=230&q=90" alt="Viral Aksi Bos Blue Bird Nyamar Jadi Sopir Taksi Keliling Jakarta">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Viral Aksi Bos Blue Bird Nyamar Jadi Sopir Taksi Keliling Jakarta</h2>
#                                     </a>
#                                 </article>
#                                                             </div>
#                         </div>
#                     </div>
#
#                     <!-- s:banner logonavigasi -->
#                                          <!-- e:banner logonavigasi -->
#
#                 </div>
#             </div>
#         </div>
#
#     </li>
#                     <li class="dropdown hover">
#         <a href="https://www.cnnindonesia.com/olahraga" class="gtm_navbar_olahraga" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="5" dtr-ttl="Olahraga">Olahraga</a>
#
#         <div class="dropdown_menu">
#             <div class="container mt20 mb20">
#                 <div class="grid_row">
#
#                     <div class="col_2">
#                         <div class="f13 mt15 mb15"></div>
#
#                                                                                     <a href="https://www.cnnindonesia.com/olahraga/sepakbola">Sepakbola</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/olahraga/moto-gp">Moto GP</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/olahraga/f1">F1</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/olahraga/raket">Raket</a>
#                                                                         </div>
#
#                     <div class="col_8 pr20">
#                         <div class="box">
#                             <div class="title_box">BERITA TERBARU</div>
#                             <div class="grid_row gap cols">
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/olahraga/20230524034601-142-953203/bintang-malaysia-diincar-klub-korea-selangor-pasang-harga-mahal">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2023/01/07/malaysia-thailand-aff-soccer-1_169.jpeg?w=230&q=90" alt="Bintang Malaysia Diincar Klub Korea, Selangor Pasang Harga Mahal">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Bintang Malaysia Diincar Klub Korea, Selangor Pasang Harga Mahal</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/olahraga/20230524192704-142-953620/pssi-bantah-harga-tiket-indonesia-vs-argentina-dijual-rp1-5-juta">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2022/12/18/final-piala-dunia-2022-argentina-vs-prancis-50_169.jpeg?w=230&q=90" alt="PSSI Bantah Harga Tiket Indonesia vs Argentina Dijual Rp1-5 Juta">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">PSSI Bantah Harga Tiket Indonesia vs Argentina Dijual Rp1-5 Juta</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/olahraga/20230524024237-142-953199/tak-betah-di-saudi-ronaldo-diklaim-ingin-tinggalkan-al-nassr">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2023/04/19/fbl-ksa-hilal-nassr-1_169.jpeg?w=230&q=90" alt="Tak Betah di Saudi, Ronaldo Diklaim Ingin Tinggalkan Al Nassr">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Tak Betah di Saudi, Ronaldo Diklaim Ingin Tinggalkan Al Nassr</h2>
#                                     </a>
#                                 </article>
#                                                             </div>
#                         </div>
#                     </div>
#
#                     <!-- s:banner logonavigasi -->
#                                          <!-- e:banner logonavigasi -->
#
#                 </div>
#             </div>
#         </div>
#
#     </li>
#                     <li class="dropdown hover">
#         <a href="https://www.cnnindonesia.com/teknologi" class="gtm_navbar_teknologi" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="6" dtr-ttl="Teknologi">Teknologi</a>
#
#         <div class="dropdown_menu">
#             <div class="container mt20 mb20">
#                 <div class="grid_row">
#
#                     <div class="col_2">
#                         <div class="f13 mt15 mb15"></div>
#
#                                                                                     <a href="https://www.cnnindonesia.com/teknologi/teknologi-informasi">Teknologi Informasi</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/teknologi/sains">Sains</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/teknologi/telekomunikasi">Telekomunikasi</a>
#                                                                         </div>
#
#                     <div class="col_8 pr20">
#                         <div class="box">
#                             <div class="title_box">BERITA TERBARU</div>
#                             <div class="grid_row gap cols">
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/teknologi/20230524184209-213-953608/operator-seluler-buka-suara-soal-pungutan-dari-bakti-kominfo">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2022/10/06/bakti-kominfo-targetkan-7000-bts-di-daerah-3t-pada-2024_169.jpeg?w=230&q=90" alt="Operator Seluler Buka Suara Soal Pungutan Dari BAKTI Kominfo">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Operator Seluler Buka Suara Soal Pungutan Dari BAKTI Kominfo</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/teknologi/20230524141138-199-953467/uap-air-terlacak-menyembur-ratusan-km-dari-bulannya-saturnus">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2019/07/09/605e0bd8-20a5-4c92-ab7d-d3bcf8966315_169.jpeg?w=230&q=90" alt="Uap Air Terlacak Menyembur Ratusan Km dari Bulannya Saturnus">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Uap Air Terlacak Menyembur Ratusan Km dari Bulannya Saturnus</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/teknologi/20230523110045-192-952819/hoaks-ledakan-pentagon-nyebar-di-twitter-prediksi-pakar-terbukti">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2018/10/10/1e95b889-8f65-44b7-b1c8-add95a56b133_169.jpeg?w=230&q=90" alt="Hoaks Ledakan Pentagon Nyebar di Twitter, Prediksi Pakar Terbukti">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Hoaks Ledakan Pentagon Nyebar di Twitter, Prediksi Pakar Terbukti</h2>
#                                     </a>
#                                 </article>
#                                                             </div>
#                         </div>
#                     </div>
#
#                     <!-- s:banner logonavigasi -->
#                                          <!-- e:banner logonavigasi -->
#
#                 </div>
#             </div>
#         </div>
#
#     </li>
#                     <li class="dropdown hover">
#         <a href="https://www.cnnindonesia.com/otomotif" class="gtm_navbar_otomotif" dtr-evt="header" dtr-sec="first navbar" dtr-act="first navbar" onclick="_pt(this)" dtr-idx="7" dtr-ttl="Otomotif">Otomotif</a>
#
#         <div class="dropdown_menu">
#             <div class="container mt20 mb20">
#                 <div class="grid_row">
#
#                     <div class="col_2">
#                         <div class="f13 mt15 mb15"></div>
#
#                                                                                     <a href="https://www.cnnindonesia.com/otomotif/tren">Tren</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/otomotif/mobil">Mobil</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/otomotif/motor">Motor</a>
#                                                                                                                 <a href="https://www.cnnindonesia.com/otomotif/e-vehicle">E-Vehicle</a>
#                                                                         </div>
#
#                     <div class="col_8 pr20">
#                         <div class="box">
#                             <div class="title_box">BERITA TERBARU</div>
#                             <div class="grid_row gap cols">
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/otomotif/20230524160631-588-953539/kapan-pak-prabowo-dan-pak-ganjar-bicara-soal-mobil-listrik">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2022/04/27/mobil-listrik-volkswagen-id-4-jadi-yang-terlaris-di-kuartal-pertama-2022-5_169.jpeg?w=230&q=90" alt="Kapan Pak Prabowo dan Pak Ganjar Bicara soal Mobil Listrik?">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Kapan Pak Prabowo dan Pak Ganjar Bicara soal Mobil Listrik? </h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/otomotif/20230524190457-587-953613/nongol-di-iims-esemka-absen-di-giias-2023">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2023/02/16/jokowi-kunjungi-booth-esemka-di-iims-2023-2_169.jpeg?w=230&q=90" alt="Nongol di IIMS, Esemka Absen di GIIAS 2023">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Nongol di IIMS, Esemka Absen di GIIAS 2023</h2>
#                                     </a>
#                                 </article>
#                                                                 <article class="col_4">
#                                     <a href="https://www.cnnindonesia.com/otomotif/20230523182033-592-953091/mengenal-fitur-hill-start-assist-pada-mobil-bagaimana-cara-kerjanya">
#                                         <span class="ratiobox ratio_16_9 mb10">
#                                             <span class="ratiobox_content lqd">
#
#                                                 <img src="https://akcdn.detik.net.id/visual/2018/06/10/0771bfe8-c9f5-4bde-ba5b-0a33265d7bd6_169.jpeg?w=230&q=90" alt="Mengenal Fitur Hill Start Assist pada Mobil, Bagaimana Cara Kerjanya?">
#                                             </span>
#                                         </span>
#                                         <h2 class="title">Mengenal Fitur Hill Start Assist pada Mobil, Bagaimana Cara Kerjanya? </h2>
#                                     </a>
#                                 </article>
#                                                             </div>
#                         </div>
#                     </div>
#
#                     <!-- s:banner logonavigasi -->
#                                         <!-- e:banner logonavigasi -->
#
#                 </div>
#             </div>
#         </div>
#
#     </li>
#                             <li class="dropdown hover">
# ...
#             </span>
#         </span>
#
#         <span class="box_text">
#
#
#             <h2 class="title">Kebakaran Rumah Makan Jasunda BSD, 1 Karyawan Alami Luka Bakar</h2>
#
#
#                             <span class="kanal"> Nasional </span>
#
#
#
#                                                 <span class="date"> &bull; 1 minggu yang lalu<!--2023-05-24 21:01:56--></span>
#                                     </span>
#     </a>
# </article>            </div>
#
#     <div class="text_center mt20 mb20">
#         <div class="pagination">
#             <a class="active" href="https://www.cnnindonesia.com/tag/kebakaran" dtr-evt="halaman" dtr-sec="halaman 1" dtr-act="halaman 1" onclick="_pt(this)">1</a><a class="" href="https://www.cnnindonesia.com/tag/kebakaran/2" dtr-evt="halaman" dtr-sec="halaman 2" dtr-act="halaman 2" onclick="_pt(this)">2</a><a class="" href="https://www.cnnindonesia.com/tag/kebakaran/3" dtr-evt="halaman" dtr-sec="halaman 3" dtr-act="halaman 3" onclick="_pt(this)">3</a><a class="" href="https://www.cnnindonesia.com/tag/kebakaran/4" dtr-evt="halaman" dtr-sec="halaman 4" dtr-act="halaman 4" onclick="_pt(this)">4</a><a>...</a><a class="" href="https://www.cnnindonesia.com/tag/kebakaran/176" dtr-evt="halaman" dtr-sec="halaman 176" dtr-act="halaman 176" onclick="_pt(this)">176</a><a className="next" href="https://www.cnnindonesia.com/tag/kebakaran/2" dtr-evt="halaman" dtr-sec="halaman selanjutnya" dtr-act="halaman selanjutnya" onclick="_pt(this)">
#                     <svg width="9" height="13" fill="none" xmlns="http://www.w3.org/2000/svg">
#                         <path d="m.795 2.063 4.58 4.59-4.58 4.59 1.41 1.41 6-6-6-6-1.41 1.41Z" fill="#333">
#                         </path>
#                     </svg>
#                 </a>        </div>
#     </div>
#
# </div>
#
#
#         </div>
#
#         <div class="r_content">
#
#             <!-- s:banner mediumrectangle1 -->
#
# <div class="banner_reg">
# <ins class="dtk-ins-3784"></ins>
# <script>
# create_ins('keyword',dtk_keyword,'3784');
# </script>
# </div>            <!-- e:banner mediumrectangle1 -->
#
#             <!-- s:banner mediumrectangle2 -->
#                         <!-- e:banner mediumrectangle2 -->
#
#         </div>
#
#         <div class="clearfix"></div>
#
#     </div>
# </section>
#
#         <footer id="footer">
#
#     <div class="foot1">
#         <div class="container clearfix">
#
#             <a href="" id="scrollup" title="Kembali ke atas" dtr-evt="footer" dtr-sec="back to top" dtr-act="back to top" dtr-ttl="back to top" onclick="_pt(this)">
#                 <span class="icon icon-up"></span>
#             </a>
#             <div class="fl">
#                 <a href="https://www.cnnindonesia.com/" class="gtm_footer_home block" dtr-evt="footer" dtr-sec="logo cnn" dtr-act="logo cnn" dtr-ttl="logo" onclick="_pt(this)">
#                     <img id="" src="https://cdn.cnnindonesia.com/cnnid/images/cnn-foot-logo.webp?v=10.8.7" alt="News We Can Trust"  width="233" height="37">
#                 </a>
#             </div>
#
#         </div>
#     </div>
#
#     <div class="foot2">
#         <div class="container">
#
#             <div class="grid_row gap">
#
#                 <div class="col_4">
#
#                     <div class="grid_row">
#                     	<!--
#                         <div class="col_2">
#                             <a href="https://www.cnnindonesia.com/" class="gtm_footer_home">
#                                 <img id="logo_foot" src="https://cdn.cnnindonesia.com/cnnid/images/logo.png?v=10.8.7" alt="logo cnn">
#                             </a>
#                         </div>
#                         -->
#                         <div class="col_9 f13">
#                             <div class="pl5">
#                                 <div class="mb5">Menyajikan berita terhangat langsung melalui handphone Anda</div>
#                                 <a href="//app.cnnindonesia.com" target="_blank" dtr-evt="footer" dtr-sec="download apps" dtr-act="download apps" dtr-ttl="download apps" onclick="_pt(this)">DOWNLOAD SEKARANG</a> <br><br>
#
#                             </div>
#                         </div>
#                     </div>
#
#                 </div>
#
#                 <div class="col_5">
#
#                     <div class="box">
#                         <div class="title_box">TELUSURI</div>
#                         <ul class="foot_menu">
#
#                                                                                             <li><a href="https://www.cnnindonesia.com/nasional" class="gtm_footer_nasional" dtr-evt="footer" dtr-sec="kanal" dtr-act="kanal" dtr-ttl="nasional" onclick="_pt(this)">Nasional</a></li>
#                                                                                                                             <li><a href="https://www.cnnindonesia.com/internasional" class="gtm_footer_internasional" dtr-evt="footer" dtr-sec="kanal" dtr-act="kanal" dtr-ttl="internasional" onclick="_pt(this)">Internasional</a></li>
#                                                                                                                             <li><a href="https://www.cnnindonesia.com/ekonomi" class="gtm_footer_ekonomi" dtr-evt="footer" dtr-sec="kanal" dtr-act="kanal" dtr-ttl="ekonomi" onclick="_pt(this)">Ekonomi</a></li>
#                                                                                                                             <li><a href="https://www.cnnindonesia.com/olahraga" class="gtm_footer_olahraga" dtr-evt="footer" dtr-sec="kanal" dtr-act="kanal" dtr-ttl="olahraga" onclick="_pt(this)">Olahraga</a></li>
#                                                                                                                             <li><a href="https://www.cnnindonesia.com/teknologi" class="gtm_footer_teknologi" dtr-evt="footer" dtr-sec="kanal" dtr-act="kanal" dtr-ttl="teknologi" onclick="_pt(this)">Teknologi</a></li>
#                                                                                                                             <li><a href="https://www.cnnindonesia.com/otomotif" class="gtm_footer_otomotif" dtr-evt="footer" dtr-sec="kanal" dtr-act="kanal" dtr-ttl="otomotif" onclick="_pt(this)">Otomotif</a></li>
#                                                                                                                                                                                         <li><a href="https://www.cnnindonesia.com/hiburan" class="gtm_footer_hiburan" dtr-evt="footer" dtr-sec="kanal" dtr-act="kanal" dtr-ttl="hiburan" onclick="_pt(this)">Hiburan</a></li>
#                                                                                                                             <li><a href="https://www.cnnindonesia.com/gaya-hidup" class="gtm_footer_gaya-hidup" dtr-evt="footer" dtr-sec="kanal" dtr-act="kanal" dtr-ttl="gaya-hidup" onclick="_pt(this)">Gaya Hidup</a></li>
#
#                             <li><a href="https://www.berbuatbaik.id/?utm_source=cnn&utm_medium=footer&utm_campaign=berbuatbaikid" class="gtm_footer_berbuatbaikid" dtr-evt="footer" dtr-sec="berbuatbaikid" dtr-act="berbuatbaikid" dtr-ttl="berbuatbaikid" onclick="_pt(this)">berbuatbaik.id</a></li>
#                         </ul>
#                         <a href="https://www.cnnindonesia.com/tv"
#                             class="cnntv mt10"
#                             dtr-evt="footer"
#                             dtr-sec="cnn tv"
#                             dtr-act="cnn tv"
#                             dtr-ttl="button cnn tv"
#                             onclick="_pt(this)"
#                         >CNN TV</a>
#                     </div>
#
#                 </div>
#
#                 <div class="col_3">
#
#                     <div class="box pl20">
#                         <div class="title_box">IKUTI KAMI</div>
#                         <div class="sosmed mt10">
#                             <a href="https://www.facebook.com/CNNindonesia" class="fb gtm_button_facebook" dtr-evt="footer" dtr-sec="socmed cnn" dtr-act="socmed cnn" dtr-ttl="facebook" onclick="_pt(this)"><i class="icon icon-facebook"></i></a>
#                             <a href="https://twitter.com/cnnindonesia" class="tw gtm_button_twitter" dtr-evt="footer" dtr-sec="socmed cnn" dtr-act="socmed cnn" dtr-ttl="twitter" onclick="_pt(this)"><i class="icon icon-twitter"></i></a>
#                             <a href="https://instagram.com/cnnindonesia" class="ig gtm_button_instagram" dtr-evt="footer" dtr-sec="socmed cnn" dtr-act="socmed cnn" dtr-ttl="instagram" onclick="_pt(this)"><i class="icon icon-instagram"></i></a>
#                         </div>
#                     </div>
#
#                 </div>
#
#             </div>
#
#         </div>
#     </div>
#
#     <div class="container text_center f13">
#
#         &copy; 2023 Trans Media, CNN name, logo and all associated elements (R) and © 2023 Cable News Network, Inc. A Time Warner Company. All rights reserved. CNN and the CNN logo are registered marks of Cable News Network, Inc., displayed with permission. <br>
#         <a href="https://www.cnnindonesia.com/tentang-kami" class="gtm_tentangkami">Tentang Kami</a> |
#         <a href="https://www.cnnindonesia.com/tentang-kami#redaksi" class="gtm_redaksi">Redaksi</a> |
#         <a href="https://www.cnnindonesia.com/pedoman-media-siber" class="gtm_pedomanmediasiber">Pedoman Media Siber</a> |
#         <a href="https://www.cnnindonesia.com/karir" class="gtm_karir">Karir</a> |
#         <a href="https://www.cnnindonesia.com/disclaimer" class="gtm_disclaimer">Disclaimer</a> <br>
#         <a href="https://us.cnn.com/" rel="nofollow">CNN U.S.</a> | <a href="https://www.cnn.com/" rel="nofollow">CNN International</a> | <a href="https://cnnespanol.cnn.com/" rel="nofollow">CNN en ESPAÑOL</a> | <a href="http://www.cnnchile.com" rel="nofollow">CNN Chile</a> | <a href="http://www.cnnmexico.com" rel="nofollow">CNN México</a> | <a href="https://arabic.cnn.com/" rel="nofollow">العربية</a> | <a href="https://www.cnn.co.jp/" rel="nofollow">日本語</a> | <a href="https://www.cnnturk.com/" rel="nofollow">Türkçe</a>
#
#     </div>
#
# </footer>
#         <script src="https://cdn.detik.net.id/libs/livecounter/detikLiveUserCounterResponse.js?v=2023052421"></script><script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/imgLiquid-min.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/jquery.caroufredsel.min.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/jquery.sticky-kit.min.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/cnn.iklan.controller.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/cnn.ads.controller.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/idTabs.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/controller.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/datetime_pick.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://cdn.detik.net.id/libs/detik-vertical/js/refresh.js?v=cnn.10.8.7"></script>
#
#
#
# <script src="https://cdn.cnnindonesia.com/cnnid/js/breakingnews.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://www.gstatic.com/firebasejs/3.6.2/firebase.js"></script>
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/firebase-msg.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/cnn.custom.js?v=10.8.7"></script>
#
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/local-storage-cleaner.js?v=10.8.7"></script>
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/cnn-indonesia.js?v=10.8.7"></script>
#
# <script type="text/javascript" src="https://cdn.cnnindonesia.com/cnnid/js/handle.form.js?v=10.8.7"></script>
#
#
# <script type="text/javascript">
#     function buildCbCovid() {
#         !(function () {
#             "use strict";
#             window.addEventListener("message", function (a) {
#                 if (void 0 !== a.data["datawrapper-height"])
#                     for (var e in a.data["datawrapper-height"]) {
#                         var t = document.getElementById("datawrapper-chart-" + e) || document.querySelector("iframe[src*='" + e + "']");
#                         t && (t.style.height = a.data["datawrapper-height"][e] + "px");
#                     }
#             });
#
#             window.addEventListener("message", function (a) {
#                     if (void 0 !== a.data["datawrapper-height"])
#                         for (var e in a.data["datawrapper-height"]) {
#                             var t = document.getElementById("datawrapper-chart-" + e) || document.querySelector("iframe[src*='" + e + "']");
#                             t && (t.style.height = a.data["datawrapper-height"][e] + "px");
#                         }
#                 });
#         })();
#     }
#
#     function buildSticky() {
#         return $("[data-sticky_column]")
#             .stick_in_parent({
#                 parent: "[data-sticky_parent]",
#                 offset_top: 85, //45+40
#                 inner_scrolling: false,
#                 spacer: false,
#             })
#             .on("sticky_kit:bottom", function (e) {
#                 if ($(this).parents(".r_content").length) {
#                     $(this).parents(".r_content").css("position", "static");
#                 } else {
#                     $(this).parent().css("position", "static");
#                 }
#             })
#             .on("sticky_kit:unbottom", function (e) {
#                 if ($(this).parents(".r_content").length) {
#                     $(this).parents(".r_content").css("position", "relative");
#                 } else {
#                     $(this).parent().css("position", "relative");
#                 }
#             })
#             .on("sticky_kit:stick", function (e) {
#                 if ($("#top_banner").hasClass("top_banner_bar")) {
#                     $(".is_stuck").css("margin-top", 90); //50+40
#                     $("#nav.is_stuck").css("margin-top", "0!important");
#                 }
#             })
#             .on("sticky_kit:unstick", function (e) {
#                 if ($("#top_banner").hasClass("top_banner_bar")) {
#                     $(".sticky").css("margin-top", 0);
#                     $("[data-sticky_column]").css("margin-top", 0);
#                 }
#             });
#     }
#
#     $(".toggle-vid-terkait").click(function () {
#         $(".vid-terkait").slideToggle();
#     });
#
#     // function build slider video pilihan redaksi
#     $(function () {
#         $("#slide_pilihan_redaksiTV").carouFredSel({
#             width: '100%',
#             auto: false,
#             height: "auto",
#             align: false,
#             scroll: {
#                 items: 2
#             },
#             prev: "#prev_pilihan",
#             next: "#next_pilihan"
#         });
#     });
#
#     var iframeList = document.querySelectorAll('[cbdinamisiframe]');
#     for (var i = 0, len = iframeList.length; i < len; i++) {
#         resizeIframe(iframeList[i]);
#     }
# </script>
#         <!--s:banner tagfoot-->
#
# <script type="text/javascript" src="https://newrevive.detik.com/delivery/asyncjs.php"></script>
# <script type="text/javascript" src="https://cdn.detik.net.id/commerce/desktop/js/detik.ads.controller-new.js"></script>        <!--e:banner tagfoot-->
#
#
#     <script defer src="https://static.cloudflareinsights.com/beacon.min.js/v52afc6f149f6479b8c77fa569edb01181681764108816" integrity="sha512-jGCTpDpBAYDGNYR5ztKt4BQPGef1P0giN6ZGVUi835kFF88FOmmn8jBQWNgrNd8g/Yu421NdgWhwQoaOPFflDw==" data-cf-beacon='{"rayId":"7cc6137ec88e8807","version":"2023.4.0","b":1,"token":"4cf051f05c0d42a493dcea7a629fa891","si":100}' crossorigin="anonymous"></script>
# </body>
#
# </html>

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
articles = soup.find_all("article")

# %%
article_tags = []
for article in articles:
    article_tags.append(article)
    #print(article, end="\n"*2)
print(article_tags)
# Out:
# [<article class="col_4">
# <a href="https://www.cnnindonesia.com/nasional/20230524203912-12-953654/polisi-tetapkan-3-tersangka-kasus-mafia-tanah-senilai-rp18-t-di-jakut">
# <span class="ratiobox ratio_16_9 mb10">
# <span class="ratiobox_content lqd">
# <img alt
# <span class="ratiobox ratio_16_9 box_img">
# <span class="ratiobox_content lqd">
# <img alt="Kebakaran Landa Lapak Limbah Oli dan Rumah Warga di Tangerang" src="https://akcdn.detik.net.id/visual/2021/07/19/ilustrasi-kebakaran-2_169.jpeg?w=280&amp;q=90" title="img-title"/>
# </span>
# </span>
# <span class="box_text">
# <h2 class="title">Kebakaran Landa Lapak Limbah Oli dan Rumah Warga di Tangerang</h2>
# <span class="kanal"> Nasional </span>
# <span class="date"> • 6 hari yang lalu<!--2023-05-24 21:01:56--></span>
# </span>
# </a>
# </article>, <article class="">
# <a href="https://www.cnnindonesia.com/nasional/20230512101855-20-948642/kebakaran-rumah-makan-jasunda-bsd-1-karyawan-alami-luka-bakar">
# <span class="ratiobox ratio_16_9 box_img">
# <span class="ratiobox_content lqd">
# <img alt="Kebakaran Rumah Makan Jasunda BSD, 1 Karyawan Alami Luka Bakar" src="https://akcdn.detik.net.id/visual/2016/06/15/22de3799-3c23-48ec-80fc-a9f30a8fc52a_169.jpg?w=280&amp;q=90" title="img-title"/>
# </span>
# </span>
# <span class="box_text">
# <h2 class="title">Kebakaran Rumah Makan Jasunda BSD, 1 Karyawan Alami Luka Bakar</h2>
# <span class="kanal"> Nasional </span>
# <span class="date"> • 1 minggu yang lalu<!--2023-05-24 21:01:56--></span>
# </span>
# </a>
# </article>]

# %%
url_list = []
title_list = []
img_list = []
for article_tag in article_tags:
    a_tag = article_tag.find('a')
    h2_tag = article_tag.find('h2')
    img_tag = article_tag.find('img')
    img_tag = img_tag['src']
    
    if a_tag is not None:
        url = a_tag['href']
        url_list.append(url)
        #print("URL:", url)
        
    if h2_tag is not None:
        title = h2_tag.get_text()
        title_list.append(title)
        #print("Title:", title)
        
    if img_tag is not None:
        #img_src = img_tag.get_text()
        img_list.append(img_tag)
    
print("URL:", url_list)
print("Title:", title_list)
print("Image:",img_list)
# Out:
# URL: ['https://www.cnnindonesia.com/nasional/20230524203912-12-953654/polisi-tetapkan-3-tersangka-kasus-mafia-tanah-senilai-rp18-t-di-jakut', 'https://www.cnnindonesia.com/nasional/20230524203827-12-953653/densus-88-tangkap-seorang-terduga-teroris-di-kota-malang', 'https://www.cnnindonesia.com/nasional/20230524202830-32-953652/dasco-bantah-dugaan-gerindra-terima-duit-kasus-bakti-kominfo', 'https://www.cnnindonesia.com/internasional/20230524112712-134-953338/pembakaran-al-quran-di-rusia-pemimpin-chechen-murka-tuduh-ukraina', 'https://www.cnnindonesia.com/internasional/20230524121645-134-953364/bos-wagner-salahkan-rusia-belgorod-diserang-pejabat-pura-pura-bodoh', 'https://www.cnnindonesia.com/internasional/20230524181517-113-953595/kenapa-kashmir-sensitif-sampai-china-saudi-ancam-boikot-forum-g20', 'https://www.cnnindonesia.com/ekonomi/20230524201032-92-953644/krl-bandara-soetta-tambah-jadi-56-perjalanan-mulai-1-juni-2023', 'https://www.cnnindonesia.com/ekonomi/20230524150751-92-953509/inflasi-inggris-tak-lagi-dua-digit-pertama-kali-sejak-agustus-2022', 'https://www.cnnindonesia.com/ekonomi/20230524190122-92-953612/viral-
# 30  Pabrik Plastik di Jakbar Kebakaran, 15 Unit Mo...
# 31  Rumah Tahfiz Al Quran di Makassar Kebakaran Ge...
# 32  Kebakaran Landa Lapak Limbah Oli dan Rumah War...
# 33  Kebakaran Rumah Makan Jasunda BSD, 1 Karyawan ...
#
#                                           Link Berita
# 24  https://www.cnnindonesia.com/nasional/20230523...  \
# 25  https://www.cnnindonesia.com/internasional/202...
# 26  https://www.cnnindonesia.com/internasional/202...
# 27  https://www.cnnindonesia.com/tv/20230522170435...
# 28  https://www.cnnindonesia.com/nasional/20230521...
# 29  https://www.cnnindonesia.com/nasional/20230519...
# 30  https://www.cnnindonesia.com/nasional/20230519...
# 31  https://www.cnnindonesia.com/nasional/20230519...
# 32  https://www.cnnindonesia.com/nasional/20230517...
# 33  https://www.cnnindonesia.com/nasional/20230512...
#
#                                           Link Gambar
# 24  https://akcdn.detik.net.id/visual/2020/01/01/2...
# 25  https://akcdn.detik.net.id/visual/2021/07/19/i...
# 26  https://akcdn.detik.net.id/visual/2023/05/22/k...
# 27  https://akcdn.detik.net.id/visual/2023/05/22/t...
# 28  https://akcdn.detik.net.id/visual/2020/01/01/c...
# 29  https://akcdn.detik.net.id/visual/2015/08/18/8...
# 30  https://akcdn.detik.net.id/visual/2020/01/01/c...
# 31  https://akcdn.detik.net.id/visual/2021/07/19/i...
# 32  https://akcdn.detik.net.id/visual/2021/07/19/i...
# 33  https://akcdn.detik.net.id/visual/2016/06/15/2...

# %%
df[24:].to_excel('kebakaran 1.xlsx', index=False)

# %% [markdown]
# ## Page (crashed)

# %%
base_url = "https://www.cnnindonesia.com/tag/kebakaran/"

# %%
article_tags = []
url_list = []
title_list = []

df = pd.DataFrame({
    'Judul Berita Kebakaran Halaman 2-5' : title_list,
    'Link Berita': url_list
})

articles_per_page = 34
num_of_articles = df.shape[0] // articles_per_page

for i in range(num_of_articles):
    # get thefirst index at article
    start_index = i * articles_per_page
    # get the last 10 
    end_index = start_index + articles_per_page

for page_num in range(start_index,end_index):
    url = base_url + str(page_num)
    # print(url)
    
    response = requests.get(url)
    response.raise_for_status()
    
    soup = BeautifulSoup(response.content, 'html.parser')
    articles = soup.find_all("article")
    
    for article in articles:
        article_tags.append(article)
        
        for article_tag in article_tags:
            a_tag = article_tag.find('a')
            h2_tag = article_tag.find('h2')
    
            if a_tag is not None:
                url = a_tag['href']
                url_list.append(url)
                #print("URL:", url)
                
            if h2_tag is not None:
                title = h2_tag.get_text()
                title_list.append(title)
                #print("Title:", title)
    
#print("URL:", url_list)
#print("Title:", title_list)

# %%
print("URL:", url_list)
print("Title:", title_list)

# %%
combine_kebakaran_df = pd.DataFrame()
for i in range(num_of_articles):
    combine = df[start_index:end_index].tail(10)
    combine_kebakaran_df = pd.concat([combine_kebakaran_df, combine])

print(combine_kebakaran_df)

# %%
df = pd.DataFrame({
    'Judul Berita Kebakaran Halaman 2-5' : title_list,
    'Link Berita': url_list
})

articles_per_page = 34
num_of_articles = df.shape[0] // articles_per_page

combine_kebakaran_df = pd.DataFrame()

for i in range(num_of_articles):
    # get thefirst index at article
    start_index = i * articles_per_page
    # get the last 10 
    end_index = start_index + articles_per_page
    
    combine = df[start_index:end_index].tail(10)
    combine_kebakaran_df = pd.concat([combine_kebakaran_df, combine])

print(combine_kebakaran_df)

# %%
combine_kebakaran_df.to_excel('combined_results.xlsx', index=False)

# %% [markdown]
# ## Page 2-5

# %%
URL = "https://www.cnnindonesia.com/tag/kebakaran/5"
page = requests.get(URL)
#print(page.text)
soup = BeautifulSoup(page.content, "html.parser")
articles = soup.find_all("article")
article_tags = []
for article in articles:
    article_tags.append(article)
    #print(article, end="\n"*2)
#print(article_tags)
url_list = []
title_list = []
img_list = []

for article_tag in article_tags:
    a_tag = article_tag.find('a')
    h2_tag = article_tag.find('h2')
    img_tag = article_tag.find('img')
    img_tag = img_tag['src']
    
    if a_tag is not None:
        url = a_tag['href']
        url_list.append(url)
        #print("URL:", url)
        
    if h2_tag is not None:
        title = h2_tag.get_text()
        title_list.append(title)
        #print("Title:", title)
    
    if img_tag is not None:
        img_list.append(img_tag)
#print("URL:", url_list)
#print("Title:", title_list)

df = pd.DataFrame({
    'Judul Berita' : title_list,
    'Link Berita': url_list,
    'Link Gambar': img_list
})
#print(df[24:])
df[24:].to_csv('kebakaran 5.csv', index=False)

# %%
dir = '../news_titles_urls/kebakaran/'

csv_files = glob.glob(dir + '*.csv')

dfs = []

for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df) 
combined_df = pd.concat(dfs, ignore_index=True)
combined_df.to_csv('Kebakaran.csv', index=False)

# %%
df = pd.read_csv("../news_titles_urls/kebakaran/Kebakaran.csv")
df.to_excel("kebakaran.xlsx", index=False)

# %% [markdown]
# # Kejahatan (Polisi)

# %% [markdown]
# ## Page 1-5

# %%
URL = "https://www.cnnindonesia.com/tag/polisi/2"
page = requests.get(URL)
#print(page.text)
soup = BeautifulSoup(page.content, "html.parser")
articles = soup.find_all("article")
article_tags = []
for article in articles:
    article_tags.append(article)
    #print(article, end="\n"*2)
#print(article_tags)
url_list = []
title_list = []
img_list = []

for article_tag in article_tags:
    a_tag = article_tag.find('a')
    h2_tag = article_tag.find('h2')
    img_tag = article_tag.find('img')
    img_tag = img_tag['src']
    
    if a_tag is not None:
        url = a_tag['href']
        url_list.append(url)
        #print("URL:", url)
        
    if h2_tag is not None:
        title = h2_tag.get_text()
        title_list.append(title)
        #print("Title:", title)
    
    if img_tag is not None:
        img_list.append(img_tag)
#print("URL:", url_list)
#print("Title:", title_list)

df = pd.DataFrame({
    'Judul Berita' : title_list,
    'Link Berita': url_list,
    'Link Gambar': img_list
})
#print(df[24:])
df[24:].to_csv('kejahatan 5.csv', index=False)

# %%
dir = '../news_titles_urls/kejahatan/'

csv_files = glob.glob(dir + '*.csv')

dfs = []

for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df) 
combined_df = pd.concat(dfs, ignore_index=True)
combined_df.to_csv('Kejahatan.csv', index=False)

# %%
df = pd.read_csv("../news_titles_urls/kejahatan/Kejahatan.csv")
df.to_excel("kejahatan.xlsx", index=False)
